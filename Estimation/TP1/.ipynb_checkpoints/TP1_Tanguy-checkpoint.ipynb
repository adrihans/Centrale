# %% [markdown]
# ## II. Méthode Accept-Reject

# %%
import numpy as np
from scipy.stats import uniform, norm, cauchy
import matplotlib.pyplot as plt

# %%
X = np.linspace(-3, 3, 100)
f = norm.pdf
f_dist = norm.rvs
g = cauchy.pdf
g_dist = cauchy.rvs
M = np.sqrt(2*np.pi/np.e)

# %%
plt.plot(X, f(X))
plt.plot(X, M*g(X))

# %% [markdown]
# 1.

# %%
# Accept-reject Method
def Accepte_rejecte(f, g, g_dist, M, nb_it=1000):
    res = []
    for i in range(nb_it):
        u = uniform.rvs(loc=0, scale=1)
        x = g_dist()
        while (f(x) / (M * g(x)) < u):
            u = uniform.rvs(loc=0, scale=1)
            x = g_dist()
        res.append(x)
    return res

# %%
res = Accepte_rejecte(f, g, g_dist, 5, nb_it=10000)

# %%
plt.plot(X, f(X))
_ = plt.hist(res, density=True, bins=X)

# %% [markdown]
# 2.

# %%
plt.plot(X, g(X))

# %% [markdown]
# 3.
#
# Euh... On constate rien ?

# %%
plt.plot(X, g(X))
_ = plt.hist(res, density=True, bins=X)

# %% [markdown]
# 4.

# %%
ttt = norm.rvs(loc=5, scale=1, size=10000)

_ = plt.hist(res, density=True, bins=X, fc=(1, 0, 0, 0.5))
_ = plt.hist(ttt, density=True, bins=X+5, fc=(0, 1, 0, 0.5))

# %%
ttt = norm.rvs(loc=0, scale=1, size=10000)

_ = plt.hist(res, density=True, bins=X, fc=(1, 0, 0, 0.5))
_ = plt.hist(ttt, density=True, bins=X, fc=(0, 1, 0, 0.5))
